# %%
from datascience import *
import numpy as np

# %% [markdown]
# ### Why Names?

# %% [markdown]
# A cell with arithmetic but no names is difficult to interpret.

# %%
# Option 1
40 * 11.41

# %%
40 * 52 * 11.41

# %% [markdown]
# On January 1, 2026, the MN Minimum Wage increased to to $11.41/hour.

# %%
# Option 2
mn_hourly_minimum_wage = 11.41
hours_per_week = 40
weeks_per_year = 52

# %%
hours_per_year = hours_per_week * weeks_per_year

# %%
hours_per_year

# %%
weekly_wages = hours_per_week * mn_hourly_minimum_wage
weekly_wages

# %%
yearly_wages = hours_per_year * mn_hourly_minimum_wage
yearly_wages

# %% [markdown]
# ## Numbers ##

# %%
30

# %%
10 * 3    # int

# %%
10 / 3    # float

# %%
10 / 2

# %%
10 ** 3

# %%
10 ** 0.5

# %%
1234567 ** 890

# %%
10 / 3

# %%
75892745.215489247589274985712 # can only store so many digits

# %%
75892745.215489247589274985712 - 75892745.21548925 # Python can't handle arithmetic this precise

# %%
(13 ** 0.5) ** 2 # not exactly 13 because of precision issues

# %%
int(10 / 5)

# %%
int(10 / 4)

# %%
float(3)

# %%
6 / 4

# %%
6 / 4000

# %%
6 / 400000000000000000000000000000000000000000000000000000000 # scientific notation works as expected

# %%
400000000000000000000000000000000000000000000000000000000 * 1.5e-56 # can use scientific notation as input

# %%
1.5e-56 # we can check what it gives as output

# %%
x = 5

# %%
2x

# %%
2 * x

# %% [markdown]
# ## Strings ##

# %%
'Flavor'

# %%
# The line below causes a name error
# Flavor

# %%
"Flavor"

# %%
'Don't always use single quotes'

# %%
"Don't always use single quotes"

# %%
'straw' 'berry' # concatenation

# %%
'straw' + 'berry' # concatenation

# %%
'Tom' + 'Sawyer' # spaces aren't added for you

# %%
'Tom' + ' ' + 'Sawyer'

# %%
x = 'straw'
y = 'berry'
x + y

# %%
x y

# %%
'ha' * 100

# %%
'lo' * 5.5

# %%
'ha' + 10

# %%
'ha' + str(10)

# %%
int('3')

# %%
int('3.0')

# %%
int(float('3.0'))

# %%
dot_oh = '.0'
float('3' + dot_oh)

# %% [markdown]
# ## Types ##

# %%
type(10)

# %%
a = 10

# %%
type(a)

# %%
type(4.5)

# %%
type('abc')

# %%
type(Table.read_table('nba_salaries.csv'))

# %%
type(True)

# %%
abs(-5)

# %%
type(abs)

# %% [markdown]
# ## Arrays ##

# %%
first_four = make_array(1, 2, 3, 4)

# %%
first_four

# %%
first_four * 2

# %%
first_four ** 2

# %%
first_four + 1

# %%
first_four # array is unchanged, just like when we call show/select/drop on Table

# %%
next_four = make_array(5, 6, 7, 8)

# %%
first_four + next_four

# %%
only_three = make_array(5, 6, 7)

# %%
# This line will cause an error 
# first_four + only_three

# %%
str_array = make_array('ha', 'he', 'ho')

# %%
str_array

# %%
str_array * 4

# %%
next_four

# %%
next_four.item(0)

# %%
next_four.item(1)

# %%
sum(next_four)

# %%
np.average(next_four)

# %%
len(next_four)

# %% [markdown]
# ## Columns of Tables are Arrays ##

# %%
nba = Table.read_table('nba_salaries.csv').where('season', 2020).drop('season')
nba.show(5)

# %%
warriors = nba.where('team', 'Golden State Warriors')
warriors.show(5)

# %%
warriors.select('salary')

# %%
type(warriors.select('salary'))

# %%
warriors.column('salary')

# %%
np.average(warriors.column('salary')) # since it's an array, we can use numpy functions on it

# %%
suns = nba.where('team', 'Phoenix Suns')

# %%
np.average(warriors.column('salary')) - np.average(suns.column('salary')) # Warriors have higher average salary than Suns in 2020

# %%
np.sum(warriors.column('salary')) - np.sum(suns.column('salary'))

# %%
# wait so why do the Warriors have higher average salary but lower total salary than the Suns?

# %%
warriors.num_rows

# %%
suns.num_rows
