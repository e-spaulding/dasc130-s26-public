# %%
import matplotlib
from datascience import *
# %matplotlib inline
import matplotlib.pyplot as plots
import numpy as np
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## The SD and Bell Shaped Curves

# %%
births = Table.read_table('baby.csv')

# %%
births.hist('Maternal Height', bins = np.arange(56.5, 72.6, 1))
plots.show();

# %% [markdown]
# (slides)

# %% [markdown]
# ## Central Limit Theorem ##

# %%
united = Table.read_table('united.csv')
united_bins = np.arange(-20, 300, 10)
united

# %%
united.hist('Delay', bins=united_bins)
plots.show()

# %%
def one_sample_mean(sample_size):
    """ 
    Takes a sample from the population of flights 
    and computes its mean
    """
    sampled_flights = ...
    return ...

# %%
def ten_thousand_sample_means(sample_size):
    '''
    Returns an array of 10,000 sample means, where each sample mean is the mean of a 
    random sample of the given size.
    '''
    means = make_array()
    for i in np.arange(10000):
        ...
        ...
    return ...

# %%
Table().with_column(
    'Mean of 100 flight delays', sample_means_100).hist(bins=20)

print('Population Average:', delay_mean)
plots.show();

# %%
sample_means_400 = ten_thousand_sample_means(400)
Table().with_column(
    'Mean of 400 flight delays', sample_means_400).hist(bins=20)

print('Population Average:', delay_mean)
plots.show();
